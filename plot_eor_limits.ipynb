# %%
import eor_limits
import importlib
importlib.reload(eor_limits)
import matplotlib.pyplot as plt

# %%
paper_redshifts={
    "beardsley_2016": [7.1]
}

# %%
paper_redshifts={
    "li_2019": [6.5],
    "patil_2017": [10.1],
    "trott_2020": [6.5],
    "hera_2022": [7.93],
    "rahimi_2021": [6.5],
    "yoshiura_2021": [14.2],
    "dillon_2014": [9.518],
    "beardsley_2016": [7.1],
    "kolopanis_2019": [8.37]
}

# %%
eor_limits.make_plot(
    #plot_as_points=["li_2019", "barry_2019", "patil_2017", "trott_2020", "mertens_2020", "hera_2022", "rahimi_2021", "yoshiura_2021"],
    plot_as_points=["patil_2017", "trott_2020", "mertens_2020", "rahimi_2021", "yoshiura_2021"],
    redshift_range=[5.5, 11],
    #redshift_range=[6.5,7.1],
    delta_squared_range = [1e0,3e8],
    shade_limits=False,
    papers=["paciga_2013", "dillon_2014","dillon_2015","beardsley_2016","patil_2017", "kolopanis_2019", "li_2019", "barry_2019","mertens_2020", "trott_2020","rahimi_2021", "yoshiura_2021", "hera_2022","wilensky_2023",  "hera_2023", "hera_2025"],
    paper_redshifts=paper_redshifts,
    fontsize=30,
    theory_legend=False,
    bold_papers=["li_2019", "barry_2019","rahimi_2021", "yoshiura_2021","trott_2020", "wilensky_2023", "hera_2025"],
    colormap="plasma_r"
)
# Out:
# [0.5, 0.065, 0.18, 0.18, 0.16, 0.231, 0.27, 0.053, 0.067, 0.083, 0.103, 0.128, 0.31, 0.185, 0.222, 0.258, 0.295, 0.332, 0.369, 0.517, 0.554, 0.591, 0.628, 0.665, 0.702, 0.739, 0.775, 0.812, 0.96, 0.997, 1.034, 1.071, 1.108, 1.145, 1.182, 1.219, 1.256, 1.403, 1.44, 1.477, 1.514, 1.551, 1.588, 1.625, 1.662, 0.145, 0.174, 0.203, 0.232, 0.261, 0.29, 0.319, 0.349, 0.3776, 0.4937, 0.523, 0.552, 0.581, 0.61, 0.639, 0.668, 0.697, 0.726, 0.755, 0.784, 0.9, 0.929, 0.958, 0.987, 1.017, 1.046, 1.075, 1.104, 1.133, 1.162, 1.191, 1.22, 1.249, 1.278, 1.307, 1.336, 1.365, 1.394, 1.423, 1.452, 1.481, 1.51, 1.539, 1.568, 1.597, 0.075, 0.1, 0.133, 0.179, 0.238, 0.319, 0.432, 0.142, 0.212, 0.283, 0.354, 0.425, 0.495, 0.566, 0.637, 0.708, 0.135, 0.177, 0.248, 0.319, 0.389, 0.46, 0.531, 0.602, 0.672, 0.743, 0.814, 0.885, 0.956, 1.026, 0.128, 0.192, 0.256, 0.32, 0.384, 0.448, 0.512, 0.576, 0.64, 0.704, 0.768, 0.832, 0.896, 0.96, 0.258, 0.27, 0.34, 0.41, 0.48, 0.55, 0.62, 0.69, 0.76, 0.83, 0.9, 0.97, 1.05, 
# ...

# %%
eor_limits.make_plot(papers=["beardsley_2016", "dillon_2014"], paper_redshifts=paper_redshifts, shade_limits=False)
# Out:
# [0.231, 0.27, 0.065]
